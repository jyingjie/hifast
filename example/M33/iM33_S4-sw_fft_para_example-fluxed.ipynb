# %% [markdown]
# **Read README.md first.**
#
# author: Xu Chen, 2021/12/4， xuchen21@mails.ucas.ac.cn

# %%
# import h5py
import numpy as np
import matplotlib.pyplot as plt
from hifast.ripple.util import *
from hifast.ripple.sw_fft import *
from copy import deepcopy

# %%
# 这里是已经去过基线的-bld.hdf5文件，如果标记了RFI，使用含-rfi.hdf5的文件
subname = '/data/inspur_disk01/userdir/xuc/FAST/M33/new_21/example/data_S/M33_OTF_1_MultiBeamOTF-M01_W-20210731-specs_T-flux-bld-rfi.hdf5'
sub = Read_hdf5(Args(subname))

# %% [markdown]
# # example polar yy
#
# 以偏振yy为例去除驻波

# %%
data = sub.get_data(polar='yy')
freq = sub.freq
is_on = sub.fs['is_on'][:]
is_rfi =time_rfi = sub.fs['is_rfi'][:]

# %% [markdown]
# # RFI
#
# 这个示例文件里没有时域RFI，如果要测试参数，可以使用以下代码调节参数：

# %% [raw]
# from hifast.ripple.markRFI import mask_time_rfi, mask_freq_rfi
# # 单通道RFI
# narr_rfi = mask_freq_rfi(data,freq,frange = None,rtype = 'long-time',times = 30,thr = 30,
#                          ext_add=0,rfi_width_lim = [0,2],plot = True,ylim=[-1,10])
# # 常见的1380 GPS emission
# s_rfi = mask_time_rfi(data,freq, rtype = 'short-freq',frange =[1360,1390],times = 3,thr = 1,
#                       ext_add=0,rfi_width_lim = 10,plot = True,rms_frange=[1390,1400])
# # 可能是大卫星的RFI
# l_rfi = mask_time_rfi(data,freq, rtype = 'long-freq',frange =[1400,1460],times = 2,thr = 0,
#                       ext_add=50,rfi_width_lim = 50,plot = True)

# %% [markdown]
# 本文档中的is_rfi只包括一些很小的偏振标记的rfi

# %%
sub.plot_waterfall(data,per_vmin_max=.90,figsize=(18,4),cmap = 'plasma')

# %% [markdown]
# # RMS
#
# 目前rms是手动指定选一个没有信号和干扰范围。用于判断大的信号。例如```--rms_frange 1425 1435```

# %%
import mpl_interactions.ipyplot as iplt

# %%
# %matplotlib ipympl
spec = deepcopy(data[0,:])
def test_gauss(freq,sigma):
    from hifast.utils.misc import smooth1d
    sm = smooth1d(spec,method='gaussian',sigma=sigma)
    return sm

fig,ax = plt.subplots(figsize=(10,2))
iplt.plot(freq,spec,label = 'ori')
controls = iplt.plot(freq, test_gauss,  sigma=np.arange(2, 20, 1),xlim = [1425,1435],
                     ylim=[-.1,.1],color = 'C1',label='smooth')
iplt.title("sigma is {sigma:.2f}", controls=controls['sigma'])
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# VBox()
# VBox(children=(HBox(children=(IntSlider(value=0, description='sigma', max=17, readout=False), Label(value='2.0…

# %% [markdown]
# (如果发现了交互没反应，重启内核并跳过前面画瀑布图即可

# %% [markdown]
# # MW range
# 有MW的区域，下面会被强制替代为驻波。例如下图的判断，如果输入了```--mw_frange 1420.3,1420.8```，那么MW将都被替代。注意过长将影响对驻波估计的效果，所以也可以不输入(None). 默认```[0,0]```

# %%
mw_frange = (1420.3,1420.8)
# %matplotlib inline
plt.plot(freq,np.mean(data,axis = 0))
plt.vlines(mw_frange,ymin=0,ymax = .5)
plt.xlim(1420.0,1423)
# Out:
# (1420.0, 1423.0)

# %% [markdown]
# 接下来，考虑离散fourier变换的两端会拟合效果很差，可以在下一步切去两端或者在两端延长(未整合，但是测试过)，使得最终的结果保持良好的去驻波效果。这里不再演示

# %% [markdown]
# # Replace RFI or strong sources
#
# 这里'near ripple'使用高流量处附近的驻波替代源或RFI。例如
# * `--times_thr`:大于RMS这么多倍的会被置为噪声(不平滑)
# * `--times_s_thr`:大于RMS这么多倍的会被替代(第一次平滑)
# * `--times_s_thr2`:大于RMS这么多倍的会被替代(第二次平滑)
# * `--rfi_width_lim`: 要替换的rfi/源，频率上的宽度应该大于一阈值(通道数)
# * `--ext_sec`: (接上面的)并向两边扩展通道数
# * `--ext_freq`: 先扩展边缘(MHz)，再寻找强流量两边的最低点，先使用左/右边的一段更干净一点的代替强流量处，默认1.3即可

# %%
# %matplotlib ipympl
from hifast.ripple.markRFI import real_rms,rms
def repalce_near_single(freq, times_s_thr=1.5, times_s_thr2=3,times_thr=4, rms_sigma=6,ext_freq=1.3,
                        rms_frange=[1410,1415], rfi_width_lim=30, ext_sec=30,):
    """
    replace mw, rfi or others by near ripple section

    times_thr: above ~ times of rms will be set noise (unsmooth)
    times_s_thr: above ~ times of rms will be replaced (smoothed once)
    times_s_thr2: above ~ times of rms will be replaced (smooth twice)
    ext_freq: extend freq range to replace (mhz)
    rfi_width_lim: rfi should contain more channels than limit
    ext_sec: extend channel number of start and end of each section
    """
    fdelta = freq[1]-freq[0]

    ext = int(np.around(ext_freq / fdelta))

    from hifast.ripple.markRFI import real_rms, rms

    MAX = np.nanmax(data)*20
    #################
    spec = deepcopy(data[tn, :])
    include = mw_use #| time_rfi[tn]
    if np.sum(include) > 0:
        spec[include] = MAX * 20   
    if times_s_thr2 is None:
        times_s_thr2 = times_s_thr
        
    # sm2 used to define replace area    
    RMS = rms(sm2, freq, rms_vrange=rms_frange)
    thr_s = RMS*times_s_thr2
    exceed_use = (sm2 > thr_s) | time_rfi[tn]
    
    # sm3 used to restrict replace area in one spectra
    if sm3 is not None:
        restrict_use = (sm3 > thr_s) | time_rfi[tn]
    else:
        restrict_use = np.full(freq.shape,True)
        
    # sm1 used to find ripples valleys
    newspec, rep_from, rep_to = replace_spec(tn, spec, freq, exceed_use, restrict_use, rfi_width_lim, ext_sec,
                           ext, RMS, MAX, sm = sm1,test = True,)

    RMS = real_rms(spec, freq, sigma=rms_sigma, rms_vrange=rms_frange)
    strange = np.where(np.abs(newspec) > times_thr * RMS)[0]
    newspec[strange] = np.random.normal(scale=RMS, size=len(strange))

    return newspec, rep_from * .1, rep_to * .1

# plot functions
def test_replace_new(freq, times_s_thr=1.5, times_s_thr2=3,times_thr=4, rms_sigma=6,ext_freq=1.3,
                        rms_frange=[1410,1415], rfi_width_lim=30, ext_sec=30,):
    newspec, rep_from, rep_to = repalce_near_single(freq, times_s_thr, times_s_thr2, times_thr, rms_sigma,ext_freq,
                        rms_frange, rfi_width_lim, ext_sec,)
    return newspec - offset * 2

def test_replace_from(freq, times_s_thr=1.5, times_s_thr2=3,times_thr=4, rms_sigma=6,ext_freq=1.3,
                        rms_frange=[1410,1415], rfi_width_lim=30, ext_sec=30,):
    newspec, rep_from, rep_to = repalce_near_single(freq, times_s_thr, times_s_thr2,times_thr, rms_sigma,ext_freq,
                        rms_frange, rfi_width_lim, ext_sec,)
    return rep_from

def test_replace_to(freq, times_s_thr=1.5, times_s_thr2=3,times_thr=4, rms_sigma=6,ext_freq=1.3,
                        rms_frange=[1410,1415], rfi_width_lim=30, ext_sec=30,):
    newspec, rep_from, rep_to = repalce_near_single(freq, times_s_thr, times_s_thr2,times_thr, rms_sigma,ext_freq,
                        rms_frange, rfi_width_lim, ext_sec,)
    return rep_to

def test_replace_thr(freq, times_s_thr=1.5, times_s_thr2=3,times_thr=4, rms_sigma=6,ext_freq=1.3,
                        rms_frange=[1410,1415], rfi_width_lim=30, ext_sec=30,):
    
    RMS = real_rms(spec,freq,sigma=rms_sigma,rms_vrange=rms_frange)

    thr_lower = RMS*times_thr
    thr = np.full(len(freq),thr_lower)
    return thr

def test_replace_s_thr(freq, times_s_thr=1.5, times_s_thr2=3,times_thr=4, rms_sigma=6,ext_freq=1.3,
                        rms_frange=[1410,1415], rfi_width_lim=30, ext_sec=30,):
    
    RMS = rms(sm1,freq,rms_vrange=rms_frange)

    thr_lower = RMS*times_s_thr
    thr = np.full(len(freq),thr_lower)
    return thr

def test_replace_s_thr3(freq, times_s_thr=1.5, times_s_thr2=3,times_thr=4, rms_sigma=6,ext_freq=1.3,
                        rms_frange=[1410,1415], rfi_width_lim=30, ext_sec=30,):
    
    RMS = rms(sm1,freq,rms_vrange=rms_frange)

    thr_lower = RMS*times_s_thr
    thr = np.full(len(freq),thr_lower)
    return thr - offset * 2

def test_replace_s_thr2(freq, times_s_thr=1.5, times_s_thr2=3,times_thr=4, rms_sigma=6,ext_freq=1.3,
                        rms_frange=[1410,1415], rfi_width_lim=30, ext_sec=30,):
    
    RMS = rms(sm2,freq,rms_vrange=rms_frange)

    thr_lower = RMS*times_s_thr2
    thr = np.full(len(freq),thr_lower)
    return thr - offset

def test_replace_diff(freq, times_s_thr=1.5, times_s_thr2=3,times_thr=4, rms_sigma=6,ext_freq=1.3,
                        rms_frange=[1410,1415], rfi_width_lim=30, ext_sec=30,):
    newspec, rep_from, rep_to = repalce_near_single(freq, times_s_thr, times_s_thr2,times_thr, rms_sigma,ext_freq,
                        rms_frange, rfi_width_lim, ext_sec,)
    diff = ((spec - newspec) != 0)
    return diff * .05 - offset * 2

# %% [markdown]
# 通过单条谱线尝试参数，划分被replace的范围.之前已经确定了rms_sigma=6,rms_frange=[1390,1400]，这里测试其他参数，使得不要替代过多的噪声而速度变慢。

# %% [markdown]
# # first iteration
#
# 第一次迭代。如果对弱源流量要求不高，可以不进行第二次迭代

# %% [markdown]
# 首先,先进行第一次平滑。使用了时间和频率两个方向，更利于保留弱源。

# %%
from hifast.ripple.util import do_smooth
sm_args = {}
sm_args['s_method_t'] = 'gaussian'
sm_args['s_sigma_t'] = 5
sm_args['s_method_freq'] = 'gaussian'
sm_args['s_sigma_freq'] = 3
sm_args['is_rfi'] = is_rfi
data_sm1 = do_smooth(data, **sm_args)
# Out:
# Smoothing t ...
# Smoothing freq ...

# %% [markdown]
# 由于时间上的平滑可能扩大应该替代的区域，一旦```'s_method_t'!='none```且```restrict_bound = True```，将进行只有freq方向sigma为rms_sigma的高斯平滑来限定替代区域。

# %%
sm_args3 = {}
sm_args3['s_method_freq'] = 'gaussian'
sm_args3['s_sigma_freq'] = 6
data_sm3 = do_smooth(data, **sm_args3)
# Out:
# Smoothing freq ...

# %% [markdown]
# 可以分别尝试使用`mw_frange`与否的效果，**理论上不给MW范围限制更准**
#
# mw_use = (freq > mw_frange[0])&(freq < mw_frange[1])

# %%
mw_use = np.full(freq.shape,False)

# %%
# %matplotlib ipympl
offset = .05
xlim = [1415,1430]
ylim = [-.2,.2]

tn = 2000
spec = deepcopy(data[tn])
sm1 = data_sm1[tn]
sm2 = data_sm1[tn]
sm3 = data_sm3[tn]

fig = plt.figure(figsize=(15,3))
ax = fig.add_subplot(111)
iplt.plot(freq,spec,label='original',alpha = .5)
plt.plot(freq,is_rfi[tn]*.08,'k',alpha=.5,label='is_rfi')

ax.plot(freq,sm1,'m',alpha=.5,label='smooth1')
# iplt.plot(freq,mw_use*1.5,label='mw',alpha = .5)
controls = iplt.plot(freq, test_replace_to,
                     times_thr=np.arange(1.,10,.25),
                     times_s_thr=np.arange(0.2,8,.2),
#                      times_s_thr2=np.arange(0.,6,.2),
                     rfi_width_lim=np.arange(2,50,2).astype(int), 
                     ext_sec=np.arange(2,50,2).astype(int),
                     ext_freq=np.arange(1.3,5,0.1),
                     xlim=xlim,ylim=ylim,label='rep to')
iplt.plot(freq,test_replace_from,controls = controls,
                     alpha=.8,xlim=xlim,ylim=ylim,label = 'copy from')
iplt.plot(freq,test_replace_new,controls = controls, c='g',
                     alpha=.5,xlim=xlim,ylim=ylim,label = 'after replace')
iplt.plot(freq,test_replace_diff,'r--',controls = controls,
                     alpha=.5,xlim=xlim,ylim=ylim,label = 'rep area')
# ax.plot(freq,sm2 - offset,'m-.',alpha=.5,label='smooth2')

ax.plot(freq,sm3 - offset * 2,'m--',alpha=.5,label='smooth3')

iplt.plot(freq,test_replace_thr,'k:',controls = controls,
                     alpha=.5,xlim=xlim,ylim=ylim,label = 'thr')
iplt.plot(freq,test_replace_s_thr,'k--',controls = controls,
                     alpha=.5,xlim=xlim,ylim=ylim,label = 's_thr1')
# iplt.plot(freq,test_replace_s_thr2,'k-.',controls = controls,
#                      alpha=.5,xlim=xlim,ylim=ylim,label = 's_thr2')
iplt.plot(freq,test_replace_s_thr3,'k',controls = controls, ls = (0, (3, 1, 1, 1, 1, 1)),# 'densely dashdotdotted'
                     alpha=.5,xlim=xlim,ylim=ylim,label = 's_thr1')
ax.grid();ax.legend(loc='right')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# VBox()
# VBox(children=(HBox(children=(IntSlider(value=0, description='times_thr', max=35, readout=False), Label(value=…

# %% [markdown]
# ## replace
# 前面确定好了参数，现在处理所有谱线

# %%
rep_args = {}
rep_args['rms_sigma'] = 6
rep_args['rms_frange'] = [1410, 1415]
rep_args['times_thr'] = 4
rep_args['times_s_thr'] = 3
rep_args['times_s_thr2'] = 2 # 第二次迭代参数在第一次不使用
rep_args['rfi_width_lim'] = 20
rep_args['ext_sec'] = 30
rep_args['ext_freq'] = 1.3
# rep_args['mw_frange'] = mw_frange

# %%
data_rep = replace_rfi(data, freq, time_rfi=is_rfi, method='near_ripple',
                                 data_sm1 = data_sm1, data_sm2 = None,data_sm3 = data_sm3, **rep_args)
# Out:
# INFO: Replace RFI with near_ripple method ... [hifast.ripple.sw_fft]
# 100%|██████████| 6057/6057 [00:13<00:00, 433.88it/s]

# %% [markdown]
# 替代后瀑布图的效果

# %%
# %matplotlib inline
sub.plot_waterfall(data_rep,per_vmin_max=.90,figsize=(18,4),cmap = 'plasma')

# %% [markdown]
# # FFT remove 1MHz ripples
#
# 第一次迭代中的去驻波
#
# * ```--sw_base```: 去除傅里叶空间的常数成分。如果基线整体偏离0, 此参数设为True可缓解。
# * ```--sw_periods```: 去除的驻波成分。后可接多个字符。默认为```1mhz 2mhz 0_04mhz```. 字符与对应的驻波周期为：
#    * 字符: 驻波周期
#    * 1mhz: 1.08mhz
#    * 2mhz: 1.92mhz
#    * 0_04mhz: 0.039 mhz
#
# * ```--check_2mhz```: 若为True，如果输入Beam 6文件，将在```--sw_periods```中添加'2mhz', 如果输入的不是Beam 6文件，则删除'2mhz'(如果存在)。因为'2mhz'驻波目前只存在于Beam 6 中。
# * ```--amp_thr_mean_factor```: 傅里叶空间的平均振幅大于阈值的模，会被识别为已知的几种驻波。这里输入的是中值的倍数
# * ```--amp_thr_solo_factor```: 傅里叶空间的每一谱线的振幅大于阈值，会被选中为驻波一部分被去除。这里输入的是中值的倍数
# * ```--chan_wide```: 距离驻波的模的中心左右各(2 * chann - 1)个通道数的模，作为驻波的一部分被选中. 用于'1mhz'和'2mhz'的驻波。默认为5
# * ```--chan_narr```: 同上，窄一些的. 用于'0_04mhz'的驻波。默认为3
# * ```--choose_method```: 选择傅里叶空间中哪些模作为驻波的方法，'all'或者'interpolate'. 默认为'all'.

# %% [markdown]
# 然后对data_rep进行FFT

# %%
from hifast.ripple.sw_fft import *
sw = SW_FFT(data_rep, freq, 10)
sw.do_fft()
# Out:
# /home/xuc/.local/lib/python3.9/site-packages/hifast-master-py3.9.egg/hifast/ripple/sw_fft.py:341: RuntimeWarning: divide by zero encountered in true_divide
#   self.period = 1/self.x

# %%
x = sw.x
amp_data = sw.amp
amp_mean = np.nanmean(amp_data,axis=0)
amp_off = np.nanmean(amp_data[~is_on],axis=0)

# %%
# %matplotlib inline
plt.figure(figsize=(18,5))
vmin,vmax = percent_vminmax(amp_data,percent = .999)
plt.imshow(amp_data,origin='lower',aspect='auto',extent=(x[0],x[-1],0,amp_data.shape[0]),
        vmin=vmin,vmax=vmax,cmap='rainbow')

plt.tight_layout()
plt.colorbar()
plt.xlim(0,3)
plt.xlabel("t [$\mu s$]")
# Out:
# Text(0.5, 24.0, 't [$\\mu s$]')

# %% [markdown]
# 这里先给出Fourier空间中取模的成分范围，1.0版本中单位是通道数(之后可能改成$\mu$s)，分宽和窄两种

# %%
chan_wide=2 # 这是半宽
chan_narr=1
cw = 2 * chan_wide - 1
cn = 2 * chan_narr - 1
print(f"all_chan_wide = {cw}, all_chan_narrow = {cn}")
is_excluded_mean = np.all(is_rfi, axis=1) # 严重RFI的谱线不会参与振幅平均
# Out:
# all_chan_wide = 7, all_chan_narrow = 3

# %% [markdown]
# 内置的驻波种类，在$\mu$s轴上的大概范围，和选取的最大半通道数

# %%
sw_periods=['1mhz', '2mhz', '0_04mhz']
sw_conf = get_sw_conf(chan_wide, chan_narr)
sw_conf
# Out:
# {'1mhz': {'xlims': [[0.9, 0.95], [1.8, 1.9]], 'nchans': [4, 2]},
#  '2mhz': {'xlims': [[0.5, 0.6]], 'nchans': [4]},
#  '0_04mhz': {'xlims': [[25, 26]], 'nchans': [2]}}

# %% [markdown]
# 通过平均所有振幅，决定该波束存在哪些驻波

# %%
def test_amp_mean(x,amp_thr_mean_factor):
    sw.gen_amp_thr_s(amp_thr_mean_factor,amp_thr_solo_factor=1.4,is_on=is_on,is_excluded_mean=is_excluded_mean)
    loc = []
    for key in sw_periods:
        sw.find_sw_loc(xlims=sw_conf[key]['xlims'])
        if np.sum(sw.bingo_list) > 1:
            for b in range(len(sw.bingo_list)):
                if sw.bingo_list[b]:
                    loc += [sw.loc_list[b],]
    if len(loc)>0: loc = np.hstack((loc))
    select = np.full(x.shape,np.nan)
    
    select[loc] = 1 # modify plot height
    print("---------------------------------")
    return select 

def test_amp_mean_line(x,amp_thr_mean_factor):
    amp_thr = sw.amp_thr_mean
    return np.full(len(x),amp_thr)

# %% [markdown]
# 改变这里的amp_thr_mean_factor，选择的驻波数量会变化(print的变化在log窗口里)

# %%
# %matplotlib ipympl
ylim=[0,10]
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(211) 
ax.set_xlim(-.01,2)
iplt.plot(x,amp_mean,'.-', label = 'amp mean')
controls = iplt.plot(x,test_amp_mean,'^',
                     amp_thr_mean_factor=np.arange(1,1.7,0.0015),
                     xlim=[-.01,2],ylim=ylim,label='selected')
iplt.plot(x,test_amp_mean_line,'k--',controls=controls,
                     alpha=.5,xlim=[-.01,2],ylim=ylim,label = 'thr')
ax.grid();ax.legend(loc = 2)
ax.set_xlabel('t [$\mu$s]')
ax.set_ylabel('amp')

ax = fig.add_subplot(212) 
iplt.plot(x,amp_mean,'.-', label = 'amp mean')
iplt.plot(x,test_amp_mean,'^',controls=controls,
                     xlim=[25,26],ylim=ylim,label='selected')
iplt.plot(x,test_amp_mean_line,'k--',controls=controls,
                      alpha=.5,xlim=[25,26],ylim=ylim,label = 'thr')
ax.set_xlim(25,26)
ax.grid();ax.legend(loc = 2)
ax.set_xlabel('t [$\mu$s]')
ax.set_ylabel('amp')
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# VBox()
# VBox(children=(HBox(children=(IntSlider(value=0, description='amp_thr_mean_factor', max=466, readout=False), L…
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# find ripple 0.03861 MHz,25.89941 mu s,locate in 1036
# ---------------------------------
# VBox()
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# find ripple 0.03861 MHz,25.89941 mu s,locate in 1036
# ---------------------------------
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# find ripple 0.03861 MHz,25.89941 mu s,locate in 1036
# ---------------------------------
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# find ripple 0.03861 MHz,25.89941 mu s,locate in 1036
# ---------------------------------
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# ---------------------------------
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# ---------------------------------

# %% [markdown]
# 从平均的fourier模，可以看出明显的几种驻波，1mhz和它的倍频0.54mhz

# %% [markdown]
# 同理，决定单条谱线适用的阈值倍数amp_thr_factor和取模通道数，chan_wide,chan_narr。这里可视化测试off的谱线举例

# %%
def test_amp_solo(x,amp_thr_mean_factor,amp_thr_solo_factor,chan_wide,chan_narr):

    sw_conf1 = get_sw_conf(chan_wide, chan_narr)
    sw.gen_amp_thr_s(amp_thr_mean_factor,amp_thr_solo_factor,is_on=is_on,is_excluded_mean=is_excluded_mean)
    
    sw.is_use_sw_chan = np.full(x.shape,False)
    for key in sw_periods:
        sw.find_sw_loc(xlims=sw_conf1[key]['xlims'])
        sw.find_sw_chans(nchans=sw_conf1[key]['nchans'])
        is_use_sw_chan_amp = sw.is_use_sw_chan & (amp_data[tn] > sw.amp_thr_solo[tn])
    
    select = np.zeros_like(x)   
    select[is_use_sw_chan_amp] = amp_data[tn][is_use_sw_chan_amp] 
    print("---------------------------------")
    return select


def test_amp_solo_line(x,amp_thr_mean_factor,amp_thr_solo_factor,chan_wide,chan_narr):
    amp_thr = sw.amp_thr_solo[~is_on][tn][0]
    return np.full(len(x),amp_thr)

dx = x[1] - x[0]

# %%
tn = 0
# %matplotlib ipympl
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(211) 
xlim=[-.01,2];ylim=[0,10]
iplt.plot(x,amp_data[tn],'.-', label = f'amp tn = {tn}')
controls = iplt.plot(x,test_amp_solo,
                     amp_thr_mean_factor=1.05, # 已经固定
                     amp_thr_solo_factor=np.arange(1,2,0.02),
                     chan_wide=np.arange(1,9),chan_narr=np.arange(1,5),
                     xlim=xlim,ylim=ylim,label='selected')
iplt.plot(x,test_amp_solo_line,'k--',controls=controls,
                     alpha=.5,xlim=xlim,ylim=ylim,label = 'thr')
ax.grid();ax.legend(loc = 2)
ax.set_xlabel('t [$\mu$s]')
ax.set_ylabel('amp')

xlim=[25,26]
ax = fig.add_subplot(212) 
iplt.plot(x,amp_data[tn], label = f'amp tn = {tn}')
iplt.plot(x,test_amp_solo,controls=controls,
                     xlim=xlim,ylim=ylim,label='selected')
iplt.plot(x,test_amp_solo_line,'k--',controls=controls,
                      alpha=.5,xlim=xlim,ylim=ylim,label = 'thr')
ax.grid();ax.legend(loc = 2)
ax.set_xlabel('t [$\mu$s]')
ax.set_ylabel('amp')
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# VBox()
# VBox(children=(HBox(children=(IntSlider(value=0, description='amp_thr_solo_factor', max=49, readout=False), La…
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# ---------------------------------
# VBox()
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# ---------------------------------

# %% [markdown]
# 对于测试数据，我选择了以下参数.`choose_method`有选择所有模'all'和线性插值'interpolate'两种方式，可以分别尝试效果。

# %% [markdown]
# 现在使用完整的函数进行测试

# %%
fft_args = {}
fft_args['amp_thr_mean_factor'] = 1.05
fft_args['amp_thr_solo_factor'] = 1.4
fft_args['chan_wide'] = 2
fft_args['chan_narr'] = 1
fft_args['choose_method'] = 'all'
fft_args['sw_periods'] = ['1mhz', '2mhz', '0_04mhz']
fft_args['sw_base'] = True
fft_args['is_on'] = is_on
fft_args['is_excluded_mean'] = np.all(is_rfi, axis=1)

# %%
sw_data = fit_sw_fft(data_rep, freq, nproc=10,  **fft_args)
# Out:
# /home/xuc/.local/lib/python3.9/site-packages/hifast-master-py3.9.egg/hifast/ripple/sw_fft.py:341: RuntimeWarning: divide by zero encountered in true_divide
#   self.period = 1/self.x
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74

# %% [markdown]
# remove standing waves之后的

# %%
rmsw_data = data - sw_data

# %% [markdown]
# 下面可以画一下单条谱线的效果

# %%
from hifast.utils.misc import smooth1d

# %%
# %matplotlib inline
offset = .15

tn = 4500
fig = plt.figure(figsize=(15,4))
ax = fig.add_subplot(111)
ax.hlines([0,-offset, offset],freq[0],freq[-1],alpha = .8)
ax.plot(freq,data[tn] + offset,label='original')
ax.plot(freq,rmsw_data[tn] - offset,label='result',c='C2',alpha = .8)
ax.plot(freq,smooth1d(data[tn],method='gaussian', sigma=10) +offset,'r',label = 'smooth',alpha = .8)
ax.plot(freq,data_rep[tn],'b',label='replace mw',alpha = .8)
ax.plot(freq,sw_data[tn],c= 'C1',label='ripple')
ax.set_xlim(freq[0],freq[-1])
ax.set_ylim(-.3,.35) 
ax.grid();ax.legend();ax.set_title(f'one spec, polar yy')
# Out:
# Text(0.5, 1.0, 'one spec, polar yy')

# %% [markdown]
# 平均10条谱线效果更明显，降低了很多

# %%
# %matplotlib inline
offset = .08

fig = plt.figure(figsize=(15,4))
ax = fig.add_subplot(111)
ax.hlines([0,-offset, offset],freq[0],freq[-1],alpha = .8)
ax.plot(freq,np.mean(data[tn-5:tn+5],axis=0)+offset,label='original')
ax.plot(freq,np.mean(rmsw_data[tn-5:tn+5],axis=0) -offset,label='result',c='C2',alpha = .8)
ax.plot(freq,np.mean(smooth1d(data[tn-5:tn+5],method='gaussian', sigma=10),axis=0) +offset,'r',label = 'smooth',alpha = .8)
ax.plot(freq,np.mean(data_rep[tn-5:tn+5],axis=0),'b',label='replace mw',alpha = .8)
ax.plot(freq,np.mean(sw_data[tn-5:tn+5],axis=0),c= 'C1',label='ripple')
ax.set_xlim(freq[0],freq[-1])
ax.set_ylim(-.15,.15) 
ax.grid();ax.legend();ax.set_title(f'ten specs mean, polar yy')
# Out:
# Text(0.5, 1.0, 'ten specs mean, polar yy')

# %% [markdown]
# 瀑布图效果

# %%
sub.plot_waterfall(data,per_vmin_max=.90,figsize=(18,3),cmap = 'plasma')
sub.plot_waterfall(rmsw_data,per_vmin_max=.90,figsize=(18,3),cmap = 'plasma')

# %% [markdown]
# # second iteration
#
# 第二次迭代,对上面输出的再进行平滑

# %%
data_sm2 = do_smooth(rmsw_data, **sm_args)
data_sm3 = do_smooth(rmsw_data, **sm_args3)
# Out:
# Smoothing t ...
# Smoothing freq ...
# Smoothing freq ...

# %% [markdown]
# ## replace

# %%
# %matplotlib ipympl
offset = .1
xlim = [1415,1430]
ylim = [-.3,.3]

tn = 2000
spec = deepcopy(data[tn])
sm1 = data_sm1[tn]
sm2 = data_sm2[tn]
sm3 = data_sm3[tn]

fig = plt.figure(figsize=(15,4))
ax = fig.add_subplot(111)
iplt.plot(freq,spec,label='original',alpha = .5)
plt.plot(freq,is_rfi[tn]*.08,'k',alpha=.5,label='is_rfi')

ax.plot(freq,sm1,'m',alpha=.5,label='smooth1')
# iplt.plot(freq,mw_use*1.5,label='mw',alpha = .5)
controls = iplt.plot(freq, test_replace_to,
                     times_thr=np.arange(1.,10,.25),
                     times_s_thr=np.arange(0.2,8,.2),
                     times_s_thr2=np.arange(0.,6,.2),
                     rfi_width_lim=np.arange(2,50,2).astype(int), 
                     ext_sec=np.arange(2,50,2).astype(int),
                     ext_freq=np.arange(1.3,5,0.1),
                     xlim=xlim,ylim=ylim,label='rep to')
iplt.plot(freq,test_replace_from,controls = controls,
                     alpha=.8,xlim=xlim,ylim=ylim,label = 'copy from')
iplt.plot(freq,test_replace_new,controls = controls, c='g',
                     alpha=.5,xlim=xlim,ylim=ylim,label = 'after replace')
iplt.plot(freq,test_replace_diff,'r--',controls = controls,
                     alpha=.5,xlim=xlim,ylim=ylim,label = 'rep area')
ax.plot(freq,sm2 - offset,'m-.',alpha=.5,label='smooth2')

ax.plot(freq,sm3 - offset * 2,'m--',alpha=.5,label='smooth3')

iplt.plot(freq,test_replace_thr,'k:',controls = controls,
                     alpha=.5,xlim=xlim,ylim=ylim,label = 'thr')
iplt.plot(freq,test_replace_s_thr,'k--',controls = controls,
                     alpha=.5,xlim=xlim,ylim=ylim,label = 's_thr1')
iplt.plot(freq,test_replace_s_thr2,'k-.',controls = controls,
                     alpha=.5,xlim=xlim,ylim=ylim,label = 's_thr2')
iplt.plot(freq,test_replace_s_thr3,'k',controls = controls, ls = (0, (3, 1, 1, 1, 1, 1)),# 'densely dashdotdotted'
                     alpha=.5,xlim=xlim,ylim=ylim,label = 's_thr3')
ax.grid();ax.legend(loc='right')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# VBox()
# VBox(children=(HBox(children=(IntSlider(value=0, description='times_thr', max=35, readout=False), Label(value=…

# %%
rep_args
# Out:
# {'rms_sigma': 6,
#  'rms_frange': [1410, 1415],
#  'times_thr': 4,
#  'times_s_thr': 3,
#  'times_s_thr2': 2,
#  'rfi_width_lim': 20,
#  'ext_sec': 30,
#  'ext_freq': 1.3}

# %% [markdown]
# 使用此参数再replace，FFT

# %%
data_rep2 = replace_rfi(data, freq, time_rfi=is_rfi, method='near_ripple',
                                 data_sm1 = data_sm1, data_sm2 = data_sm2, data_sm3 = data_sm3, **rep_args)
sw_data2 = fit_sw_fft(data_rep2, freq, nproc=10,  **fft_args)
rmsw_data2 = data - sw_data2
# Out:
# INFO: Replace RFI with near_ripple method ... [hifast.ripple.sw_fft]
# 100%|██████████| 6057/6057 [00:13<00:00, 465.00it/s]
# /home/xuc/.local/lib/python3.9/site-packages/hifast-master-py3.9.egg/hifast/ripple/sw_fft.py:341: RuntimeWarning: divide by zero encountered in true_divide
#   self.period = 1/self.x
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74

# %%
# %matplotlib inline
sub.plot_waterfall(data,per_vmin_max=.90,figsize=(18,3),cmap = 'plasma')
sub.plot_waterfall(rmsw_data2,per_vmin_max=.90,figsize=(18,3),cmap = 'plasma')

# %% [markdown]
# 迭代的区别其实很小

# %%
sub.plot_waterfall(rmsw_data2 - rmsw_data,per_vmin_max=.90,figsize=(18,3),cmap = 'plasma')

# %% [markdown]
# # Run .ini

# %%
subname
# Out:
# '/data/inspur_disk01/userdir/xuc/FAST/M33/new_21/example/data_S/M33_OTF_1_MultiBeamOTF-M01_W-20210731-specs_T-flux-bld-rfi.hdf5'

# %%
# !python -m hifast.sw $subname -c ./conf/S4-sw.ini -f --outdir ./data_S/
# Out:
# ###################################Args###################################
# Command Line Args:   /data/inspur_disk01/userdir/xuc/FAST/M33/new_21/example/data_S/M33_OTF_1_MultiBeamOTF-M01_W-20210731-specs_T-flux-bld-rfi.hdf5 -c ./conf/S4-sw.ini -f --outdir ./data_S/
# Config File (./conf/S4-sw.ini):
#   frange:            ['0', 'inf']
#   nproc:             10
#   method:            fft
#   nobld:             False
#   s_method_t:        gaussian
#   s_sigma_t:         5
#   s_method_freq:     gaussian
#   s_sigma_freq:      3
#   average_every_freq:0
#   njoin:             10
#   exclude_m:         0
#   sin_f:             0.929
#   deg:               1
#   iter_twice:        True
#   rfi_method:        near_ripple
#   rms_sigma:         6
#   rms_frange:        [1410, 1415]
#   times_thr:         4
#   times_s_thr:       3
#   times_s_thr2:      2
#   ext_freq:          1.3
#   rfi_width_lim:     20
#   ext_sec:           30
#   restrict_bound:    True
#   sw_base:           True
#   sw_periods:        ['1mhz', '2mhz', '0_04mhz']
#   check_2mhz:        True
#   amp_thr_mean_factor:1.05
#   amp_thr_solo_factor:1.4
#   chan_wide:         2
#   chan_narr:         1
#   choose_method:     all
#   nspec:             200
#   func:              iter
# Defaults:
#   --bound_f:         [0.9, 0.95]
#   --mw_frange:       [0, 0]
#   --ylim:            ['auto']
#   --figsize:         (10, 7)
#   --length:          40
#
# ##########################################################################
# will overwrite the existing output file ./data_S/M33_OTF_1_MultiBeamOTF-M01_W-20210731-specs_T-flux-bld-rfi-sw.hdf5
# standing wave fitting and substract by fft
# Smoothing t ...
# Smoothing freq ...
# Smoothing freq ...
# INFO: Replace RFI with near_ripple method ... [hifast.ripple.sw_fft]
# 100%|██████████████████████████████████████| 6057/6057 [00:13<00:00, 451.29it/s]
# checking 2mhz
# beam number !=6, remove 2mhz in sw_periods if it exists
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# INFO: Replace RFI with near_ripple method ... [hifast.ripple.sw_fft]
# 100%|██████████████████████████████████████| 6057/6057 [00:14<00:00, 424.58it/s]
# checking 2mhz
# beam number !=6, remove 2mhz in sw_periods if it exists
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# Second iter ...
# Smoothing t ...
# Smoothing freq ...
# Smoothing freq ...
# INFO: Replace RFI with near_ripple method ... [hifast.ripple.sw_fft]
# 100%|██████████████████████████████████████| 6057/6057 [00:14<00:00, 415.28it/s]
# checking 2mhz
# beam number !=6, remove 2mhz in sw_periods if it exists
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# INFO: Replace RFI with near_ripple method ... [hifast.ripple.sw_fft]
# 100%|██████████████████████████████████████| 6057/6057 [00:12<00:00, 470.43it/s]
# checking 2mhz
# beam number !=6, remove 2mhz in sw_periods if it exists
# find ripple 1.08111 MHz,0.92498 mu s,locate in 37
# find ripple 0.54055 MHz,1.84996 mu s,locate in 74
# Saving...
# Saved to ./data_S/M33_OTF_1_MultiBeamOTF-M01_W-20210731-specs_T-flux-bld-rfi-sw.hdf5

# %%
name = './data_S/M33_OTF_1_MultiBeamOTF-M01_W-20210731-specs_T-flux-bld-rfi-sw.hdf5'
f = Read_hdf5(Args(name))

# %%
# %matplotlib inline
T = f.get_data(polar='yy')
f.plot_waterfall(T, per_vmin_max=.90,figsize=(18,4),cmap = 'plasma')

# %% [markdown]
# 嗯，确实去除了驻波。
